# %%
#Import pandas and numpy
import pandas as pd
import numpy as np
from numpy import random

# From matplotlib, import pyplot under the alias plt
from matplotlib import pyplot as plt

#Import Seaborn
import seaborn as sns

import glob
import os
import zipfile


from datetime import datetime
from datetime import date

import pickle

# %% [markdown]
# # Import data

# %%
#Print all contents of the datsets subfolder
for name in glob.glob('datasets/*'):
    print(name)
# Out:
# datasets/laptops.csv
# datasets/florida_hurricane_dates.pkl
# datasets/tips.csv
# datasets/marketing.csv
# datasets/NYC_Flights_2013
# datasets/avocado.csv
# datasets/romeo.txt

# %%
infile = open('datasets/florida_hurricane_dates.pkl','rb')
florida_hurricane_dates = pickle.load(infile)
infile.close()

# %%
print(florida_hurricane_dates[0])
# Out:
# 1988-08-04

# %%
#builds a dataframe from csv file
onebike_datetimes_df = pd.read_csv('https://assets.datacamp.com/production/repositories/3551/datasets/181c142c56d3b83112dfc16fbd933fd995e80f94/capital-onebike.csv')

# %%
onebike_datetimes_df.head(3)
# Out:
#             Start date             End date  Start station number  \
# 0  2017-10-01 15:23:25  2017-10-01 15:26:26                 31038
# 1  2017-10-01 15:42:57  2017-10-01 17:49:59                 31036
# 2  2017-10-02 06:37:10  2017-10-02 06:42:53                 31036
#
#                    Start station  End station number  \
# 0           Glebe Rd & 11th St N               31036
# 1  George Mason Dr & Wilson Blvd               31036
# 2  George Mason Dr & Wilson Blvd               31037
#
#                             End station Bike number Member type
# 0         George Mason Dr & Wilson Blvd      W20529      Member
# 1         George Mason Dr & Wilson Blvd      W20529      Casual
# 2  Ballston Metro / N Stuart & 9th St N      W20529      Member

# %%
onebike_datetimes_df.to_csv("datasets/onebike_datetimes.csv")

# %%
onebike_datetimes = []

import csv
csv_filename = 'datasets/onebike_datetimes.csv'
with open(csv_filename) as f:
    reader = csv.DictReader(f)
    for row in reader:
        #print(row)
        onebike_datetimes.append(row)

# %%
onebike_datetimes
# Out:
# [{'': '0',
#   'Start date': '2017-10-01 15:23:25',
#   'End date': '2017-10-01 15:26:26',
#   'Start station number': '31038',
#   'Start station': 'Glebe Rd & 11th St N',
#   'End station number': '31036',
#   'End station': 'George Mason Dr & Wilson Blvd',
#   'Bike number': 'W20529',
#   'Member type': 'Member'},
#  {'': '1',
#   'Start date': '2017-10-01 15:42:57',
#   'End date': '2017-10-01 17:49:59',
#   'Start station number': '31036',
#   'Start station': 'George Mason Dr & Wilson Blvd',
#   'End station number': '31036',
#   'End station': 'George Mason Dr & Wilson Blvd',
#   'Bike number': 'W20529',
#   'Member type': 'Casual'},
#  {'': '2',
#   'Start date': '2017-10-02 06:37:10',
#   'End date': '2017-10-02 06:42:53',
#   'Start station number': '31036',
#   'Start station': 'George Mason Dr & Wilson Blvd',
#   'End station number': '31037',
#   'End station': 'Ballston Metro / N Stuart & 9th St N',
#   'Bike number': 'W20529',
#   'Member type': 'Member'},
# ...

# %% [markdown]
# # Create date

# %%
#Order is biggest to smallest Y-M-D
two_hurricanes = [date(2016,10,7), date(2017, 6, 21)]
print(two_hurricanes)
# Out:
# [datetime.date(2016, 10, 7), datetime.date(2017, 6, 21)]

# %% [markdown]
# # Attributes of a date

# %%
print(two_hurricanes[0].year)
# Out:
# 2016

# %%
print(two_hurricanes[0].month)
# Out:
# 10

# %%
print(two_hurricanes[0].day)
# Out:
# 7

# %% [markdown]
# ![Screen%20Shot%202022-09-06%20at%201.55.31%20PM.png](attachment:Screen%20Shot%202022-09-06%20at%201.55.31%20PM.png)

# %%
print(two_hurricanes[0].weekday())
# Out:
# 4

# %% [markdown]
# # Date objects

# %%
#printing the current date and time
now = datetime.now()
print(now)
# Out:
# 2022-08-29 20:28:33.787855

# %%
current_year = now.year
current_month = now.month
current_day = now.day

# %%
print(now.year)
print(now.month)
print(now.day)
# Out:
# 2022
# 8
# 29

# %%
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 20
# 28
# 33

# %%
print('%s:%s:%s' % (now.hour, now.minute, now.second))
# Out:
# 20:28:33

# %%
print('%s/%s/%s %s:%s:%s' % (now.month, now.day, now.year, now.hour, now.minute, now.second))
# Out:
# 8/29/2022 20:28:33

# %%
black_monday = datetime(1987, 10, 10)
print(black_monday)
# Out:
# 1987-10-10 00:00:00

# %% [markdown]
# # Math with dates

# %%
d1 = date(1974, 6, 20)
d2 = date(2022, 9, 6)

l = [d1, d2]
min(l)
# Out:
# datetime.date(1974, 6, 20)

# %%
max(l)
# Out:
# datetime.date(2022, 9, 6)

# %%
delta = d2 - d1
print(delta.days)
# Out:
# 17610

# %%
from datetime import timedelta
td = timedelta(days = 29)
print(d2 + td)
# Out:
# 2022-10-05

# %%
#Incrementing variables with +=
x = 0
x +=1 #the same as x = x + 1
print(x)
# Out:
# 1

# %%
# Import date
from datetime import date

# Create a date object for May 9th, 2007
start = date(2007, 5, 9)

# Create a date object for December 13th, 2007
end = date(2007, 12, 13)

# Subtract the two dates and print the number of days
print((end - start).days)
# Out:
# 218

# %%
a = ("h", "b", "a", "c", "f", "d", "e", "g")
print(a)
# Out:
# ('h', 'b', 'a', 'c', 'f', 'd', 'e', 'g')

# %%
x = sorted(a)
print(x)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %% [markdown]
# # Turning dates into strings

# %% [markdown]
# https://strftime.org/
# https://www.tutorialspoint.com/python/time_strptime.htm#:~:text=The%20format%20parameter%20uses%20the,after%20parsing%2C%20ValueError%20is%20raised.

# %% [markdown]
# ![Screen%20Shot%202022-09-08%20at%208.19.14%20AM.png](attachment:Screen%20Shot%202022-09-08%20at%208.19.14%20AM.png)

# %%
# Assign the earliest date to first_date
first_date = min(florida_hurricane_dates)

# Convert to ISO and US formats
iso = "Our earliest hurricane date: " + first_date.isoformat()
us = "Our earliest hurricane date: " + first_date.strftime("%m/%d/%Y")

print("ISO: " + iso)
print("US: " + us)
# Out:
# ISO: Our earliest hurricane date: 1950-08-31
# US: Our earliest hurricane date: 08/31/1950

# %%
# Create a date object
andrew = date(1992, 8, 26)

# Print the date in the format 'YYYY-MM'
print(andrew.strftime('%Y-%m'))
# Out:
# 1992-08

# %%
# Create a date object
andrew = date(1992, 8, 26)

# Print the date in the format 'MONTH (YYYY)'
print(andrew.strftime('%B (%Y)'))
# Out:
# August (1992)

# %%
# Create a date object
andrew = date(1992, 8, 26)

# Print the date in the format 'YYYY-DDD'
print(andrew.strftime('%Y-%j'))
# Out:
# 1992-239

# %% [markdown]
# # Combining dates and times

# %% [markdown]
# ![Screen%20Shot%202022-09-08%20at%208.42.04%20AM.png](attachment:Screen%20Shot%202022-09-08%20at%208.42.04%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202022-09-08%20at%208.45.59%20AM.png](attachment:Screen%20Shot%202022-09-08%20at%208.45.59%20AM.png)

# %%
# Create a datetime object
dt = datetime(2017, 10, 1, 15, 26, 26)

# Print the results in ISO 8601 format
print([dt.isoformat()])
# Out:
# ['2017-10-01T15:26:26']

# %%
# Create a datetime object
dt = datetime(2017, 12, 31, 15, 19, 13)

# Replace the year with 1917
dt_old = dt.replace(year=1917)

# Print the results in ISO 8601 format
print(dt_old)
# Out:
# 1917-12-31 15:19:13

# %%
# Create dictionary to hold results
trip_counts = {'AM': 0, 'PM': 0}
  
# Loop over all trips
for trip in onebike_datetimes:
  # Check to see if the trip starts before noon
  if trip['start'].hour < 12:
    # Increment the counter for before noon
    trip_counts['AM'] += 1
  else:
    # Increment the counter for after noon
    trip_counts['PM'] += 1
  
print(trip_counts)

# %% [markdown]
# ![Screen%20Shot%202022-09-08%20at%208.53.03%20PM.png](attachment:Screen%20Shot%202022-09-08%20at%208.53.03%20PM.png)

# %%
# Import the datetime class
from datetime import datetime

# Starting string, in YYYY-MM-DD HH:MM:SS format
s = '2017-02-03 00:00:01'

# Write a format string to parse s
fmt = '%Y-%m-%d %H:%M:%S'

# Create a datetime object d
d = datetime.strptime(s, fmt)

# Print d
print(d)
# Out:
# 2017-02-03 00:00:01

# %%
# Starting string, in YYYY-MM-DD format
s = '2030-10-15'

# Write a format string to parse s
fmt = '%Y-%m-%d'

# Create a datetime object d
d = datetime.strptime(s, fmt)

# Print d
print(d)
# Out:
# 2030-10-15 00:00:00

# %%
# Starting string, in MM/DD/YYYY HH:MM:SS format
s = '12/15/1986 08:00:00'

# Write a format string to parse s
fmt = '%m/%d/%Y %H:%M:%S'

# Create a datetime object d
d = datetime.strptime(s, fmt)

# Print d
print(d)
# Out:
# 1986-12-15 08:00:00

# %%
# Write down the format string
fmt = "%Y-%m-%d %H:%M:%S"

# Initialize a list for holding the pairs of datetime objects
onebike_datetimes = []

# Loop over all trips
for (start, end) in onebike_datetime_strings:
  trip = {'start': datetime.strptime(start, fmt),
          'end': datetime.strptime(end, fmt)}
  
  # Append the trip
  onebike_datetimes.append(trip)

# %%
# Import datetime
from datetime import datetime

# Pull out the start of the first trip
first_start = onebike_datetimes[0]['start']

# Format to feed to strftime()
fmt = "%Y-%m-%dT%H:%M:%S"

# Print out date with .isoformat(), then with .strftime() to compare
print(first_start.isoformat())
print(first_start.strftime(fmt))
