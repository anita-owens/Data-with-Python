# %% [markdown]
# ## Import libraries

# %%
# Load packages
from pandas import DataFrame
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## Download 538 data

# %% [markdown]
# ### Unisex Names

# %% [markdown]
# ![Screen%20Shot%202022-08-13%20at%2012.31.30%20PM.png](attachment:Screen%20Shot%202022-08-13%20at%2012.31.30%20PM.png)

# %%
names = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/unisex-names/unisex_names_table.csv")

# %%
print(names.head())
# Out:
#    Unnamed: 0    name          total  male_share  female_share       gap
# 0           1   Casey  176544.328149    0.584287      0.415713  0.168573
# 1           2   Riley  154860.665173    0.507639      0.492361  0.015278
# 2           3  Jessie  136381.830656    0.477834      0.522166  0.044331
# 3           4  Jackie  132928.788740    0.421133      0.578867  0.157735
# 4           5   Avery  121797.419516    0.335213      0.664787  0.329574

# %% [markdown]
# ### US Births

# %% [markdown]
# ![Screen%20Shot%202022-08-13%20at%2012.29.14%20PM.png](attachment:Screen%20Shot%202022-08-13%20at%2012.29.14%20PM.png)

# %% [markdown]
# https://fivethirtyeight.com/features/some-people-are-too-superstitious-to-have-a-baby-on-friday-the-13th/

# %%
births = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/births/US_births_2000-2014_SSA.csv")

# %%
print(births.head(3))
# Out:
#    year  month  date_of_month  day_of_week  births
# 0  2000      1              1            6    9083
# 1  2000      1              2            7    8006
# 2  2000      1              3            1   11363

# %% [markdown]
# ### Pulizter data

# %% [markdown]
# ![Screen%20Shot%202022-08-13%20at%2012.32.49%20PM.png](attachment:Screen%20Shot%202022-08-13%20at%2012.32.49%20PM.png)

# %%
pulitzer = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/pulitzer/pulitzer-circulation-data.csv")

# %%
print(pulitzer.head(3))
# Out:
#              Newspaper Daily Circulation, 2004 Daily Circulation, 2013  \
# 0            USA Today               2,192,098               1,674,306
# 1  Wall Street Journal               2,101,017               2,378,827
# 2       New York Times               1,119,027               1,865,318
#
#   Change in Daily Circulation, 2004-2013  \
# 0                                   -24%
# 1                                   +13%
# 2                                   +67%
#
#    Pulitzer Prize Winners and Finalists, 1990-2003  \
# 0                                                1
# 1                                               30
# 2                                               55
#
#    Pulitzer Prize Winners and Finalists, 2004-2014  \
# 0                                                1
# 1                                               20
# 2                                               62
#
#    Pulitzer Prize Winners and Finalists, 1990-2014
# ...

# %% [markdown]
# ### Data

# %% [markdown]
# ## Write data to a csv file
