# %%
# Load packages
from pandas import DataFrame
import pandas as pd
import numpy as np
import requests

# %%
sales_subset = pd.read_csv("https://assets.datacamp.com/production/repositories/5386/datasets/5110afec30fc30bc5f3cf67b188d1513c3d6d940/sales_subset.csv")

temperatures = pd.read_csv("https://assets.datacamp.com/production/repositories/5386/datasets/47f5fde162bae3549ca7d5c26fb4c4639f100f28/temperatures.csv")

homelessness = pd.read_csv("https://assets.datacamp.com/production/repositories/5386/datasets/1a0ab2e8557930ec06473c16521874e516a216ae/homelessness.csv")

# %%
print(sales_subset.head(2))
print(temperatures.head(2))
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05       24924.5       False
# 1           1      1    A           1  2010-03-05       21827.9       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685

# %%
#The first argument is named row, if not named, then it's an integer
for type, row in sales_subset.iterrows():
    print(type + row["weekly_sales"])
# Out:
# 24924.5
# 21828.9
# 57260.43
# 17416.94
# 17562.09
# 16338.14
# 17514.41
# 16248.78
# 20102.19
# 34247.88
# 22527.56
# 15995.24
# 50617.27
# 48410.98
# 47464.5
# 47918.01
# 48770.47
# 47094.72
# 50049.73
# 49034.05
# 45849.02
# 46402.43
# 44427.02
# 43225.29
# 13764.12
# 12300.58
# 11183.08
# 9399.8
# 8029.41
# 7886.88
# 26749.02
# 19112.8
# 9807.17
# 9858.22
# 10890.85
# 15843.15
# 39990.04
# 38123.19
# 37847.49
# 37207.34
# 40588.19
# 39814.71
# 41015.88
# 38364.88
# 34956.45
# 38025.55
# 37156.55
# 37994.8
# 32277.38
# 23131.14
# 30017.92
# 19311.44
# 22984.26
# 18940.71
# 16980.17
# 15445.52
# 23437.38
# 23960.81
# 36530.02
# 22758.69
# 5809.03
# 4282.25
# 4194.61
# 7540.7
# 5548.9
# 4606.91
# 4766.38
# 3620.75
# 2944.19
# 5105.99
# 6426.96
# 1447.15
# 21156.08
# 19732.7
# 22501.62
# 20532.62
# 44639.68
# 22666.0
# 21920.57
# 18084.65
# 16561.79
# 19217.58
# 47488.83
# 17599.16
# 40213.01
# 38861.09
# 38237.58
# 35480.78
# 35269.47
# 35669.01
# 34923.35
# 35653.68
# 34750.25
# ...

# %%
for city, row in temperatures.iterrows():
    print(str(city) + row["country"])
# Out:
# 0Côte D'Ivoire
# 1Côte D'Ivoire
# 2Côte D'Ivoire
# 3Côte D'Ivoire
# 4Côte D'Ivoire
# 5Côte D'Ivoire
# 6Côte D'Ivoire
# 7Côte D'Ivoire
# 8Côte D'Ivoire
# 9Côte D'Ivoire
# 10Côte D'Ivoire
# 11Côte D'Ivoire
# 12Côte D'Ivoire
# 13Côte D'Ivoire
# 14Côte D'Ivoire
# 15Côte D'Ivoire
# 16Côte D'Ivoire
# 17Côte D'Ivoire
# 18Côte D'Ivoire
# 19Côte D'Ivoire
# 20Côte D'Ivoire
# 21Côte D'Ivoire
# 22Côte D'Ivoire
# 23Côte D'Ivoire
# 24Côte D'Ivoire
# 25Côte D'Ivoire
# 26Côte D'Ivoire
# 27Côte D'Ivoire
# 28Côte D'Ivoire
# 29Côte D'Ivoire
# 30Côte D'Ivoire
# 31Côte D'Ivoire
# 32Côte D'Ivoire
# 33Côte D'Ivoire
# 34Côte D'Ivoire
# 35Côte D'Ivoire
# 36Côte D'Ivoire
# 37Côte D'Ivoire
# 38Côte D'Ivoire
# 39Côte D'Ivoire
# 40Côte D'Ivoire
# 41Côte D'Ivoire
# 42Côte D'Ivoire
# 43Côte D'Ivoire
# 44Côte D'Ivoire
# 45Côte D'Ivoire
# 46Côte D'Ivoire
# 47Côte D'Ivoire
# 48Côte D'Ivoire
# 49Côte D'Ivoire
# 50Côte D'Ivoire
# 51Côte D'Ivoire
# 52Côte D'Ivoire
# 53Côte D'Ivoire
# 54Côte D'Ivoire
# 55Côte D'Ivoire
# ...
