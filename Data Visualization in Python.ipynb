# %%
#import pandas and numpy
import pandas as pd
import numpy as np

# From matplotlib, import pyplot under the alias plt
from matplotlib import pyplot as plt

#Import Seaborn
import seaborn as sns

#from ggplot import *

#For built-in datasets
from sklearn import datasets
#dir(datasets)

# %% [markdown]
# ## Import data

# %%
#Datasets hosted online
seattle = pd.read_csv("https://assets.datacamp.com/production/repositories/3634/datasets/6fd451508ecce0d63354fad86704236592eed8ca/seattle_weather.csv")

austin = pd.read_csv("https://assets.datacamp.com/production/repositories/3634/datasets/e76b460b41dc7ff286d78246daf3a8c324cb5587/austin_weather.csv")

climate = pd.read_csv("https://assets.datacamp.com/production/repositories/3634/datasets/411add3f8570d5adf891127fd64095020210711b/climate_change.csv")

medals_by_country = pd.read_csv("https://assets.datacamp.com/production/repositories/3634/datasets/ec663f9f509bf633d40932f65bd4cc51205689e2/medals_by_country_2016.csv")

medalist_weights = pd.read_csv("https://assets.datacamp.com/production/repositories/3634/datasets/67d7344085ace400d612275b87738615698127a3/summer2016.csv")

# %%
#Get column names
medals_by_country.columns
# Out:
# Index(['Unnamed: 0', 'Bronze', 'Gold', 'Silver'], dtype='object')

# %%
#Datasets from subfolder
tips = pd.read_csv("datasets/tips.csv")

tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ## Univariate plots

# %% [markdown]
# ### Pandas and matplotlib

# %%
medalist_weights.head(3)
# Out:
#    Unnamed: 0  ID               Name Sex   Age  Height  Weight        Team  \
# 0         158  62  Giovanni Abagnale   M  21.0   198.0    90.0       Italy
# 1         161  65  Patimat Abakarova   F  21.0   165.0    49.0  Azerbaijan
# 2         175  73          Luc Abalo   M  31.0   182.0    86.0      France
#
#    NOC        Games  Year  Season            City      Sport  \
# 0  ITA  2016 Summer  2016  Summer  Rio de Janeiro     Rowing
# 1  AZE  2016 Summer  2016  Summer  Rio de Janeiro  Taekwondo
# 2  FRA  2016 Summer  2016  Summer  Rio de Janeiro   Handball
#
#                          Event   Medal
# 0   Rowing Men's Coxless Pairs  Bronze
# 1  Taekwondo Women's Flyweight  Bronze
# 2      Handball Men's Handball  Silver

# %%
medalist_weights['Height'].plot(kind='hist')
plt.show()

# %%
medalist_weights['Weight'].plot(kind='hist')
plt.show()

# %%
# Boxplot
medalist_weights['Weight'].plot(kind='box')
plt.show()

# %%
# Bar plot
cts = medalist_weights['Medal'].value_counts()
cts.plot(kind='bar')
plt.show()

# %% [markdown]
# ### Seaborn

# %%
# Bar plot
sns.countplot(x='Sex', data=medalist_weights)
plt.show()

# %%
# Histogram using Seaborn
sns.displot(medalist_weights['Height'])
plt.show()

# %%
plt.hist(tips['total_bill'])
plt.show()

# %% [markdown]
# ## Bivariate plots

# %%
# Scatter plot
medalist_weights.plot(x='Weight', y='Height', kind='scatter')
plt.show()

# %%
sns.regplot(x='Weight', y='Height', data=medalist_weights)
plt.show()

# %% [markdown]
# You can use a boxplot to compare one continuous and one categorical variable. However, you will be using the .boxplot() method instead of the .plot() method

# %%
# Boxplot of the weight column by sex
medalist_weights.boxplot(column='Weight', by='Sex')
plt.show()

# %%
# Boxplot of the height column by sex
medalist_weights.boxplot(column='Height', by='Sex')
plt.show()

# %%
# Boxplot
sns.boxplot(x="Sex", y="Height", data=medalist_weights)
plt.show()

# %% [markdown]
# ## Facet plots

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Create a facet
# facet = sns.FacetGrid(df, col='column_a', row='column_b')
#
# # Generate a facetted scatter plot
# facet.map(plt.scatter, 'column_x', 'column_y')
# plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', col='smoker')
plt.show()

# %%
# FacetGrid of time and smoker colored by sex
facet = sns.FacetGrid(tips, col="time", row='smoker', hue='sex')

# Map the scatter plot of total_bill and tip to the FacetGrid
facet.map(plt.scatter, 'total_bill', 'tip')
plt.show()

# %%
# Bivariate scatterplot
plt.scatter(tips['tip'], tips['total_bill'], color = '#88c999', marker="*")
plt.show()

# %% [markdown]
# ## Matplotlib figure

# %% [markdown]
# ![Screen%20Shot%202022-09-04%20at%2010.17.42%20AM.png](attachment:Screen%20Shot%202022-09-04%20at%2010.17.42%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202022-09-04%20at%2010.18.42%20AM.png](attachment:Screen%20Shot%202022-09-04%20at%2010.18.42%20AM.png)

# %%
fig, ax = plt.subplots()

# %%
#3 rows 2 columns
fig, ax = plt.subplots(3, 2)
plt.show(()

# %%
plt.clf()

# %%
#Combine several subplots in a single figure
# Create a figure with 1 axes
fig, ax = plt.subplots(1, 1)

# Plot a scatter plot in the axes
ax.scatter(tips['tip'], tips['total_bill'])
plt.show()

# %%
# Create a figure with scatter plot and histogram
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(tips['tip'], tips['total_bill'])
ax2.hist(tips['total_bill'])
plt.show()

# %%
dis = sns.histplot(tips['tip'])

# Print the type
print(type(dis))
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
# Figure with 2 axes: regplot and distplot
fig, (ax1, ax2) = plt.subplots(1, 2)
sns.histplot(tips['tip'], ax=ax1)
sns.regplot(x='total_bill', y='tip', data=tips, ax=ax2)
plt.show()

# %%
# Create a figure with 1 axes
fig, ax = plt.subplots()

# Draw a displot
ax = sns.histplot(tips['total_bill'])

# Label the title and x axis
ax.set_title('Histogram')
ax.set_xlabel('Total Bill')
plt.show()
