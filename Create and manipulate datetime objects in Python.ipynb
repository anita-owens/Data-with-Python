# %% [markdown]
# # Datetimes

# %%
from datetime import datetime

# %%
black_monday = datetime(1987, 10, 10)
print(black_monday)
# Out:
# 1987-10-10 00:00:00

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 5, 16, 7, 13, 50, 62227)

# %% [markdown]
# Datetime from string

# %% [markdown]
# ![Screen%20Shot%202022-05-16%20at%207.14.58%20AM.png](attachment:Screen%20Shot%202022-05-16%20at%207.14.58%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202022-05-16%20at%207.15.48%20AM.png](attachment:Screen%20Shot%202022-05-16%20at%207.15.48%20AM.png)
